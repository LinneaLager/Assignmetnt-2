# %%
# ---- Imports ----

import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# ---- Functions ----

def read_csv():
    print('read_csv(): type("data_2.csv")) = {}'.format("data_2.csv"))
    print('')

    foo_df = pd.read_csv("data_2.csv")

    return foo_df



#---- Mainmethod ----

class DataHandler(): 
    
    #???

#example from teacher

class Thing():
    def __init__(self, param1, param2):                   #the init should read from data file into panda
        """ This is the initializer of the class """
        self.attribute1 = param1
        self.attribute2 = param2
        
    def public_func(self):                         #returns plot_vaccinations()
    
        return
    
    def _private_func(self):  #(this should be _extract_country_data(country) and returns subset of data
        
        return




#or you could mask the data 

mask = df['country'].isin([{'Afghanistan'}, {'Albania'}])
sub = df[mask][['country', 'daily_vaccinations_per_million']]
sub


#Read csv-file into pandas name it i df for dataframe with no argsparse)
df = pd.read_csv('data_2.csv')

#Fill all NaN values in all rows with 0. 
df = df.fillna(0)

#droping all the NA values

df.dropna()

 

dfGrouped = df.groupby("country")
#print(dfGrouped.last())

dfonerowpercountry = dfGrouped.last()

dffullyvaccinatedperhundred = dfonerowpercountry.filter(["country","people_fully_vaccinated_per_hundred"])

dffullyvaccinatedperhundred.sort_values(by=["people_fully_vaccinated_per_hundred"], inplace=True, ascending=True)

dffullyvaccinatedperhundred = df. dropna()

print(dffullyvaccinatedperhundred)

dffullyvaccinated = dfonerowpercountry.filter(["country","people_fully_vaccinated"])

dffullyvaccinated.sort_values(by=["people_fully_vaccinated"], inplace=True, ascending=False)


dffullyvaccinated = df. dropna()

print(dffullyvaccinated)

# %%
#df.filter(["country","total vaccinations"])

FilterbyCountry =  df['country']=="Netherlands"
netherlands = df[FilterbyCountry]
'''this filters for specific value in a column'''
print(netherlands.head())

dfGrouped = netherlands.groupby("country").sum()
'''groupby.sum groups by column specified and sums the rest of the columns'''
#print(dfGrouped)


dfFilteredColumns = df.filter(["country","total_vaccinations"])
'''df.Filter filters for certain columns to reduce dataset'''
#print(dfFilteredColumns)
dfGroupedAllCountries = dfFilteredColumns.groupby("country").sum()
'''groupby.sum groups by column specified and sums the rest of the columns'''
#print(dfGroupedAllCountries)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

sns.set_theme(style="darkgrid")

df = pd.read_csv('hotel_bookings.csv')

sns.lineplot(x = "arrival_date_month", y = "stays_in_week_nights", data = df)
plt.show()

# %%
#Locates rows connected to Afganistan. 

df.loc[df.['country'] == "Afghanistan"]

#setting flags that only applies to pandas objects.

df = pd.DataFrame()
df.flags
<Flags(allows_duplicate_labels=True)>
df.flags.allows_duplicate_labels = False
df.flags
<Flags(allows_duplicate_labels=False)>

#allow duplicate labels

df.flags['allows_duplicate_labels'] = True
df.flags
<Flags(allows_duplicate_labels=True)>

#pandas.dataframe.plot

#Line plotting with matplot lib (try)

https://www.youtube.com/watch?v=AkNGoT4wgik

#Columns wrangling

sales[revenue_per_age']= sales['Revenue']/ Sales['Customer_Age']
      

#How to rotate axis labels in seaborn

yr=sns.countplot(planets['year'])
yr.set_xsticklabels(yr.get_xticklabels(), rotation=90


#useful aggregation/description

count() - total nr of items
first(), last() -first and last item
sum() - sum of all items
prod() - product of all items

# %%
# ---- Imports ----

import pandas as pd
import argparse

# ---- Functions ----

def read_csv():
    print('read_csv(): type("data_2.csv")) = {}'.format("data_2.csv"))
    print('')

    foo_df = pd.read_csv("data_2.csv")

    return foo_df

def main():
    parser = argparse.ArgumentParser(description='Make barchart from csv.')
    parser.add_argument('-d', '--debug', help='Debugging output', action='store_true')
    parser.add_argument('csvfile', type=argparse.FileType('r'), help='Input csv file')
    args = parser.parse_args()

    print('main(): type(args.csvfile)) = {}'.format(args.csvfile))
    print('')

    foo_df = pd.read_csv(args.csvfile)

    print(foo_df.describe())
    print('')
    print(foo_df.head(5))
    print('')


#---- Mainmethod ----

class Thing():
    def __init__(self, param1, param2):
        """ This is the initializer of the class """
        self.attribute1 = param1
        self.attribute2 = param2
        
    def public_func(self):
    
        return
    
    def _private_func(self):
        
        return





if __name__ == '__main__':
    main()
